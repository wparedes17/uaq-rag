# %% [markdown]
# # UAQ Crawler Example
#
# This notebook demonstrates how to use the modular UAQ crawler to extract document links and metadata from the UAQ repository.

# %%
# Import the crawler
import sys
sys.path.append('..')

import json
from src.crawlers.uaq_crawler import UAQCrawler

# %% [markdown]
# ## Initialize the Crawler

# %%
# Create crawler instance
crawler = UAQCrawler()
print("Crawler initialized successfully!")
# Out:
# Crawler initialized successfully!

# %% [markdown]
# ## Crawl Links from First Page
#
# Extract document handles from the first page of search results.

# %%
# Crawl only the first page (max_pages=1)
print("Crawling links from first page...")
links = crawler.crawl_links(max_pages=1)

print(f"Found {len(links)} document links:")
for i, link in enumerate(links[:5]):  # Show first 5 links
    print(f"  {i+1}. {link}")

if len(links) > 5:
    print(f"  ... and {len(links) - 5} more links")
# Out:
# Crawling links from first page...
# Page 1 done
# Found 100 document links:
#   1. /handle/123456789/246
#   2. /handle/123456789/238
#   3. /handle/123456789/266
#   4. /handle/123456789/260
#   5. /handle/123456789/257
#   ... and 95 more links

# %% [markdown]
# ## Parse Document Metadata
#
# Extract metadata for each found document.

# %%
# Parse documents metadata
print("\nParsing document metadata...")
documents_data = crawler.parse_documents(links)

print(f"Parsed {len(documents_data)} documents")

# Display first document metadata
if documents_data:
    first_doc = documents_data[0]
    print("\nFirst document metadata:")
    for key, value in first_doc.items():
        if value and value[0]:  # Only show non-empty fields
            print(f"  {key}: {value[0] if len(value) == 1 else value}")
# Out:
# Parsing document metadata...
# Document /handle/123456789/246 started
# Document /handle/123456789/246 done
# Document /handle/123456789/238 started
# Document /handle/123456789/238 done
# Document /handle/123456789/266 started
# Document /handle/123456789/266 done
# Document /handle/123456789/260 started
# Document /handle/123456789/260 done
# Document /handle/123456789/257 started
# Document /handle/123456789/257 done
# Document /handle/123456789/262 started
# Document /handle/123456789/262 done
# Document /handle/123456789/255 started
# Document /handle/123456789/255 done
# Document /handle/123456789/254 started
# Document /handle/123456789/254 done
# Document /handle/123456789/258 started
# Document /handle/123456789/258 done
# Document /handle/123456789/206 started
# Document /handle/123456789/206 done
# Document /handle/123456789/212 started
# Document /handle/123456789/212 done
# Document /handle/123456789/208 started
# Document /handle/123456789/208 done
# Document /handle/123456789/229 started
# Document /handle/123456789/229 done
# Document /handle/123456789/226 started
# Document /handle/123456789/226 done
# Document /handle/123456789/227 started
# Document /handle/123456789/227 done
# Document /handle/123456789/228 started
# Document /handle/123456789/228 done
# Document /handle/123456789/231 started
# Document /handle/123456789/231 done
# Document /handle/123456789/230 started
# Document /handle/123456789/230 done
# Document /handle/123456789/235 started
# Document /handle/123456789/235 done
# Document /handle/123456789/220 started
# Document /handle/123456789/220 done
# Document /handle/123456789/232 started
# Document /handle/123456789/232 done
# Document /handle/123456789/243 started
# Document /handle/123456789/243 done
# Document /handle/123456789/240 started
# Document /handle/123456789/240 done
# Document /handle/123456789/237 started
# Document /handle/123456789/237 done
# Document /handle/123456789/234 started
# Document /handle/123456789/234 done
# Document /handle/123456789/253 started
# Document /handle/123456789/253 done
# Document /handle/123456789/236 started
# Document /handle/123456789/236 done
# Document /handle/123456789/247 started
# Document /handle/123456789/247 done
# Document /handle/123456789/259 started
# Document /handle/123456789/259 done
# Document /handle/123456789/239 started
# Document /handle/123456789/239 done
# Document /handle/123456789/249 started
# Document /handle/123456789/249 done
# Document /handle/123456789/250 started
# Document /handle/123456789/250 done
# Document /handle/123456789/1567 started
# Document /handle/123456789/1567 done
# Document /handle/123456789/1576 started
# Document /handle/123456789/1576 done
# Document /handle/123456789/1574 started
# Document /handle/123456789/1574 done
# Document /handle/123456789/1581 started
# Document /handle/123456789/1581 done
# Document /handle/123456789/1578 started
# Document /handle/123456789/1578 done
# Document /handle/123456789/1583 started
# Document /handle/123456789/1583 done
# Document /handle/123456789/1579 started
# Document /handle/123456789/1579 done
# Document /handle/123456789/1577 started
# Document /handle/123456789/1577 done
# Document /handle/123456789/1575 started
# Document /handle/123456789/1575 done
# Document /handle/123456789/1582 started
# Document /handle/123456789/1582 done
# Document /handle/123456789/1617 started
# Document /handle/123456789/1617 done
# Document /handle/123456789/1568 started
# Document /handle/123456789/1568 done
# Document /handle/123456789/1596 started
# Document /handle/123456789/1596 done
# Document /handle/123456789/1616 started
# Document /handle/123456789/1616 done
# Document /handle/123456789/1615 started
# Document /handle/123456789/1615 done
# Document /handle/123456789/1611 started
# Document /handle/123456789/1611 done
# Document /handle/123456789/1613 started
# Document /handle/123456789/1613 done
# Document /handle/123456789/1610 started
# Document /handle/123456789/1610 done
# Document /handle/123456789/1612 started
# Document /handle/123456789/1612 done
# Document /handle/123456789/1614 started
# Document /handle/123456789/1614 done
# Document /handle/123456789/1553 started
# Document /handle/123456789/1553 done
# Parsed 100 documents
#
# First document metadata:
#   id: 246
#   DC.title: La función política de los periódicos oficiales del estado de Querétaro, 1846-1867
#   DC.creator: ['Eduardo Tarsicio Zavala Rodriguez', 'curp', 'ZARE860722HMNVDD00']
#   DC.date: 2015-11
#   DC.description: Durante el siglo XIX la prensa jugó un papel de primer orden, puesto que el Estado en el proceso de su conformación y fortalecimiento se vio socorrido al contar con publicaciones que se proyectaron como vehículos favorecedores del nacionalismo y de la legitimación de los grupos políticos. Innegablemente los órganos periodísticos oficiales fueron fundamentales en la configuración del Estado mexicano. Para el caso del estado de Querétaro, a unos cuantos días del fusilamiento de Maximiliano de Habsburgo en 1867, se instauró el periódico oficial La Sombra de Arteaga, que por su longeva vida hasta la actualidad se le ha considerado decano del periodismo nacional. Poco se conoce el proceso de instauración del periódico oficial en Querétaro, por lo que vale remitirse a sus antecedentes, a fin de comprender cómo las publicaciones de corte gubernamental, tuvieron una doble función: legitimar a la autoridad en turno y difundir la ley, la cual debía publicarse para entrar en vigor. La gran diversidad de nombres que les designaron a los periódicos oficiales, es un reflejo de la época y de los intereses tanto del editor como de la autoridad. Desde 1846 año en que apareció La Columna de la Libertad, considerado como el primer periódico oficial, hasta la instauración de La Sombra de Arteaga en 1867, se publicaron en la ciudad de Querétaro poco más de diez periódicos que se autodenominaron como oficiales y uno semi-oficial. Estos órganos periodísticos escasamente conocidos constituyen el objeto principal de la presente investigación, la cual se basa en una amplia información bibliográfica, archivística y hemerográfica.
#   DC.subject: ['Doble función', 'Legitimación', 'Órganos periodísticos oficiales', 'CIENCIAS SOCIALES']
#   DC.type: Tesis de maestría
#   DC.identifier: http://ri-ng.uaq.mx/handle/123456789/246
#   citation_pdf_url: https://ri-ng.uaq.mx/bitstream/123456789/246/7/FIMAN-239302.pdf

# %% [markdown]
# ## Extract Download Links
#
# Get PDF download links for documents that have them.

# %%
# Get download links
download_links = crawler.get_download_links(documents_data)

print(f"\nFound {len(download_links)} documents with PDF downloads:")
for i, (url, filename) in enumerate(download_links[:3]):  # Show first 3
    print(f"  {i+1}. {filename}: {url[:80]}...")

if len(download_links) > 3:
    print(f"  ... and {len(download_links) - 3} more download links")
# Out:
# Found 100 documents with PDF downloads:
#   1. 246: https://ri-ng.uaq.mx/bitstream/123456789/246/7/FIMAN-239302.pdf...
#   2. 238: https://ri-ng.uaq.mx/bitstream/123456789/238/7/FIMAN-152137.pdf...
#   3. 266: https://ri-ng.uaq.mx/bitstream/123456789/266/1/RI003384.pdf...
#   ... and 97 more download links

# %% [markdown]
# ## Save Results
#
# Save the crawled data to JSON files for later use.

# %%
# Save results to files
crawler.save_to_json(links, '../data/raw/links_first_page.json')
crawler.save_to_json(documents_data, '../data/raw/documents_first_page.json')

print("\nResults saved to:")
print("  - data/raw/links_first_page.json")
print("  - data/raw/documents_first_page.json")
# Out:
# Results saved to:
#   - data/raw/links_first_page.json
#   - data/raw/documents_first_page.json

# %% [markdown]
# ## Summary

# %%
print("\n=== CRAWLING SUMMARY ===")
print(f"Pages crawled: 1")
print(f"Links found: {len(links)}")
print(f"Documents parsed: {len(documents_data)}")
print(f"PDF downloads available: {len(download_links)}")

# Count documents with titles
docs_with_titles = sum(1 for doc in documents_data if doc.get('DC.title') and doc['DC.title'][0])
print(f"Documents with titles: {docs_with_titles}")
# Out:
# === CRAWLING SUMMARY ===
# Pages crawled: 1
# Links found: 100
# Documents parsed: 100
# PDF downloads available: 100
# Documents with titles: 100

# %% [markdown]
# ## Optional: Download PDFs
#
# If you want to download the PDFs, uncomment and run the following cell:

# %%
# # Download PDFs (uncomment to run)
# print("\nDownloading PDFs...")
# downloaded_files = crawler.download_documents(documents_data)
# print(f"Downloaded {len(downloaded_files)} PDF files to data/raw/")
